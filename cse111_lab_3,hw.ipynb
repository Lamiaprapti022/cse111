# %%
#main
class CellPackage:
   def _init__(self,data, talk_time, messages, cashback, validity, price):
      self.price= int(price)
      self.data= int(data*1024)
      self.talktime= int(talk_time)
      self.messages=int(messages)
      self.validity = int(validity)
      self.cashback = int(cashback)/100*price
   def display_package_info(self):
      if self.data== 0 or self.talktime==0 or self.messages==0 or self.cashback==0:
        pass
      else:



        print("Data:{}".format(self.data*1024))
        print("Talktime:{}".format(self.talk_time))
        print("SMS/MMS:{}".format(self.messages))
        print("Validity:{}".format(self.validity))
        print("Cashback:{}".format(self.cashback))

# Driver Code
# Subtask 1: Write the CellPackage Class

pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
# Subtask 2: Check each attribute and print

pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
# Subtask 3: Check each attribute and print

pkg4 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
# Subtask 4: Check each attribute and print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6028274a0a33> in <cell line: 26>()
#      24 # Subtask 1: Write the CellPackage Class
#      25
# ---> 26 pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
#      27 print('============= Package 1 =============')
#      28 # Subtask 2: Check each attribute and print
#
# TypeError: CellPackage() takes no arguments

# %%
class CellPackage:
   def __init__(self, price, data, talk_time, messages,cashback,validity):
    self.price= int(price)
    self.data= int(data[0]*1024)
    self.talktime= int(talk_time)
    self.messages=int(messages)
    self.validity = int(validity)
    self.cashback = int(cashback[0])*price
   def _package(self):
    if self.data== 0 or self.talktime==0 or self.messages==0 or self.cashback==0:
      pass
    else:


      print("Data:{}".format(self.data*1024))
      print("Talktime:{}".format(self.talk_time))
      print("SMS/MMS:{}".format(self.messages))
      print("Validity:{}".format(self.validity))
      print("Cashback:{}".format(self.cashback))
    print()

# Driver Code
# Subtask 1: Write the CellPackage Class

pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
# Subtask 2: Check each attribute and print

pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
# Subtask 3: Check each attribute and print

pkg4 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
# Subtask 4: Check each attribute and print
# Out:
# ============= Package 1 =============
# ============= Package 2 =============
# ============= Package 3 =============

# %%
#2
class box:
  def __init__(self,height,width,beardth):
    self.height= height
    self.width= width
    self.beardth= beardth
    print("Creating a box")
    print("Volume of the box is{} cubic units".format(height*width*beardth))
  def update_box(self):
    self.height=300
    print("Creating a box")
    print("Volume of the box is{} cubic units".format(height*width*beardth))
    # Write your class code here
print("Box 1")
b1 = box([10,10,10])
print("=========================")
b1.boxDescription()
print(b1.volume())
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
b2.boxDescription()
print(b2.volume())
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
b3.boxDescription()
print(b3.volume())
# Out:
# Box 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8c603de24902> in <cell line: 15>()
#      13     # Write your class code here
#      14 print("Box 1")
# ---> 15 b1 = box([10,10,10])
#      16 print("=========================")
#      17 b1.boxDescription()
#
# TypeError: box.__init__() missing 2 required positional arguments: 'width' and 'beardth'

# %%
 class Box:
    def __init__(self, dimensions):
        self.height, self.width, self.breadth = dimensions

    def box_description(self):
        print("Creating a Box!")
        print(f"Height: {self.height}")
        print(f"Width: {self.width}")
        print(f"Breadth: {self.breadth}")
        print(f"Volume of the box is {self.volume()} cubic units.")

    def volume(self):
        return self.height * self.width * self.breadth

# Driver Code
print("Box 1")
b1 = Box([10, 10, 10])
print("=========================")
b1.box_description()
print(b1.volume())
print("-------------------------")
print("Box 2")
b2 = Box([30, 10, 10])
print("=========================")
b2.box_description()
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print(f"Volume of the box is {b2.volume()} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
b3.box_description()



# Driver Code
print("Box 1")
b1 = Box([10, 10, 10])
print("=========================")
b1.box_description()
print(b1.volume())
print("-------------------------")
print("Box 2")
b2 = Box((30, 10, 10))
print("=========================")
b2.box_description()
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
print(f"Volume of the box is {b2.volume()} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
b3.box_description()
# Out:
# Box 1
# ...
# Creating a Box!
# Height: 10
# Width: 10
# Breadth: 10
# Volume of the box is 1000 cubic units.
# 1000
# -------------------------
# Box 2
# ...
# Creating a Box!
# Height: 30
# Width: 10
# Breadth: 10
# Volume of the box is 3000 cubic units.
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# -------------------------
# Box 3
# Creating a Box!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# Box 1
# ...
# Creating a Box!
# Height: 10
# Width: 10
# Breadth: 10
# Volume of the box is 1000 cubic units.
# 1000
# -------------------------
# Box 2
# ...
# Creating a Box!
# Height: 30
# Width: 10
# Breadth: 10
# Volume of the box is 3000 cubic units.
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# -------------------------
# Box 3
# Creating a Box!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.

# %%
#3

# %%
#4
class abcTech:
    def __init__(self, name, designation, department):
        self.name = name
        self.designation = designation
        self.department = department
        self.programming_skills = []
        self.frameworks = []

    def addProgrammingSkills(self, skills):
        for skill in skills:
            self.programming_skills.append(skill)

    def addFrameworks(self, frameworks):
        for framework in frameworks:
            self.frameworks.append(framework)

    def calculateSalary(self, base_salary, working_hours):
        extra_hours = max(0,working_hours - 144)
        extra_pay = extra_hours * 800
        total_salary = base_salary + extra_pay
        return total_salary

    def printInfo(self):
        print('Name:  ' + self.name)
        print('Designation:  ' + self.designation)
        print('Department: ' + self.department)
        print('Programming Skills: ' + ', '.join(self.programming_skills))
        print('Frameworks: ' + ', '.join(self.frameworks))

    def welcomeMessage(self):
        print('Welcome to abcTech, ' + self.name + '!')

# Driver Code
print("-------------------------")
b1 = abcTech("Tamim Hasan", "Software Engineer", "Android Development")
b1.welcomeMessage()
print("-------------------------")
b1.addProgrammingSkills(["Java", "Python"])
b1.addProgrammingSkills(["Dart", "C++"])
b1.addFrameworks(["Express.js", "React"])
b1.printInfo()
print("-------------------------")
print("Your salary for this month is Tk. " + str(b1.calculateSalary(45000, 156)))
print("-------------------------")
print("-------------------------")
b2 = abcTech("Jahin Khandoker", "Senior Developer", "App Development")
b2.welcomeMessage()
print("-------------------------")
b2.addProgrammingSkills(["Java", "Dart", "Swift"])
b2.addFrameworks(["Flutter", "React Native"])
b2.addFrameworks(["Xamarin"])
b2.printInfo()
print("-------------------------")
print("Your salary for this month is Tk. " + str(b2.calculateSalary(103000, 123)))
print("-------------------------")
# Out:
# -------------------------
# Welcome to abcTech, Tamim Hasan!
# -------------------------
# Name:  Tamim Hasan
# Designation:  Software Engineer
# Department: Android Development
# Programming Skills: Java, Python, Dart, C++
# Frameworks: Express.js, React
# -------------------------
# Your salary for this month is Tk. 54600
# -------------------------
# -------------------------
# Welcome to abcTech, Jahin Khandoker!
# -------------------------
# Name:  Jahin Khandoker
# Designation:  Senior Developer
# Department: App Development
# Programming Skills: Java, Dart, Swift
# Frameworks: Flutter, React Native, Xamarin
# -------------------------
# Your salary for this month is Tk. 103000
# -------------------------

# %%
#5
class StudentDatabase:
    def __init__(self, name, student_id):
        self.name = name
        self.student_id = student_id
        self.semesters = {}

    def calculateGPA(self, courses, semester):
        total_points = 0
        total_credits = len(courses) * 3  # Each course is of 3 credits

        for course in courses:
            course_name, grade = course.split(': ')
            grade_point = float(grade)
            total_points += grade_point

        gpa = total_points / total_credits

        if semester not in self.semesters:
            self.semesters[semester] = {'courses': courses, 'gpa': gpa}

    def printDetails(self):
        print(f'Name: {self.name}')
        print(f'ID: {self.student_id}')

        for semester, data in self.semesters.items():
            courses = data['courses']
            gpa = data['gpa']

            print(f'Courses taken in {semester}: ')
            for course in courses:
                course_name, _ = course.split(': ')
                print(course_name)
            print(f'GPA: {gpa:.2f}')
    def printGrades(student):
      print(f'Grades for {student.name}')
      print(student.semesters)

# Driver Code
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
s1.printDetails()

s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
s2.printDetails()
# Out:
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 1.33
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 1.28
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 1.27

# %%
#5 new
class StudentDatabase:
    def __init__(self, name, student_id):
        self.name = name
        self.student_id = student_id
        self.semesters = {}


    def calculateGPA(self, courses, semester):
        total_points = 0
        total_credits = len(courses) * 3  # Each course is of 3 credits

        for course in courses:
            course_name, grade = course.split(': ')
            grade_point = float(grade)
            total_points += grade_point

        gpa = total_points / total_credits

        if semester not in self.semesters:
            self.semesters[semester] = {'courses': courses, 'gpa': gpa}
def printGrades(student):
    print(f'Grades for {student.name}')
    print(student.semesters)



    def printDetails(self):
        print(f'Name: {self.name}')
        print(f'ID: {self.student_id}')

        for semester, data in self.semesters.items():
            courses = data['courses']
            gpa = data['gpa']

            print(f'Courses taken in {semester}: ')
            for course in courses:
                course_name, _ = course.split(': ')
                print(course_name)
            print(f'GPA: {gpa:.2f}')
def printGrades(student):
    print(f'Grades for {student.name}')
    print(student.semesters)







# Driver Code
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')

s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')

s1.printDetails()
print('---------------------------------')
printGrades(s1)
print('---------------------------------')
s2.printDetails()
print('---------------------------------')
printGrades(s2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a6e048b9f2f4> in <cell line: 55>()
#      53 s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
#      54
# ---> 55 s1.printDetails()
#      56 print('---------------------------------')
#      57 printGrades(s1)
#
# AttributeError: 'StudentDatabase' object has no attribute 'printDetails'

# %%
#6
class Store:
    def __init__(self, initial_balance):
        self.balance = initial_balance
        self.total_items = 0
        self.inventory = {}

        print("New branch created!")

    def viewAllItems(self):
        if self.total_items == 0:
            print("There are no items in your inventory")
            return

        all_items = ', '.join(self.inventory.keys())
        print(f"All Items: {all_items}")

    def viewAllItemDetails(self):
        print(self.inventory)

    def add_item(self, item_info):
        item_name, stock, buying_price, selling_price = item_info
        if item_name in self.inventory:
            self.inventory[item_name]['stock'] += stock
        else:
            self.inventory[item_name] = {'stock': stock, 'buying_price': buying_price, 'selling_price': selling_price}
            self.total_items += 1
        self.balance -= (stock * buying_price)
        print(f"Item added: {item_name}")

    def sell_item(self, item_name, quantity):
        if item_name in self.inventory and self.inventory[item_name]['stock'] >= quantity:
            self.inventory[item_name]['stock'] -= quantity
            self.balance += (quantity * self.inventory[item_name]['selling_price'])
            print(f"Sold {quantity} {item_name}(s)")
        else:
            print(f"Sorry! {item_name} is not available at your desired quantity. Currently we have: {self.inventory.get(item_name, {'stock': 0})['stock']}")

    def restock_item(self, item_name, quantity):
        if item_name in self.inventory:
            self.inventory[item_name]['stock'] += quantity
            self.balance -= (quantity * self.inventory[item_name]['buying_price'])
            print(f"Restocked item: {item_name}, Current Stock: {self.inventory[item_name]['stock']}")
        else:
            print(f"{item_name} is not in your inventory.")

# Driver Code
print("==========================")
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")
# Out:
# ...
# New branch created!
# Current Balance: 5000
# Total items: 0
# There are no items in your inventory
# {}
# ...
# Current Balance: 5000
# Item added: ChaCha Noodles
# Current Balance: 4950
# Item added: Sparrow Shampoo
# Current Balance: 4900
# ...
# All Items: ChaCha Noodles, Sparrow Shampoo
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ...
# Current Balance: 4900
#
# Sorry! ChaCha Noodles is not available at your desired quantity. Currently we have: 10
# Current Balance: 4900
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# Sold 10 ChaCha Noodles(s)
#
# Current Balance: 4980
#
# {'ChaCha Noodles': {'stock': 0, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ...
# Current Balance: 4980
#
# ...
